# %%
import os
from IPython.display import Image 
import numpy as np
import matplotlib.pyplot as plt

# %%
cwd = os.getcwd()

# %%
print(cwd)
# Out:
# /Users/manulabricole/Documents/CDN/Math pour l_informatique

# %% [markdown]
# # Theorie

# %% [markdown]
# ## Definition

# %% [markdown]
# ### Généralités

# %% [markdown]
# --> Une transformée de Fourrier est une **fonction** (continue) qui permet de décomposer un signal **périodique** f(t) (continue) en ses composantes fréquentielles principales. Elle transforme la fonction f(t) en F(t) qui met en valeur ses différentes fréquences
#
# --> L'idée est de décomposer la fonction f(t) comme une somme de signaux.
#
# --> Les signaux sont des fonctions périodiques avec pour paramètre : L'amplitude ainsi que sa fréquence
#
# --> La transformée de Fourrier permet de détecter les fréquences principales du signal de base

# %% [markdown]
# ### Expression

# %%
Image(filename=os.path.join(cwd, "images/expression.png"))

# %% [markdown]
# - F^ est la transformée de Fourrier du signal F(x)
#
# - $\epsilon$ est la fréquence du signal. Dans le cadre d'une **image $\epsilon$ sera un vecteur (x, y) dans le plan**. Dans le cadre d'un signal sonore, la fréquence est une fréquence temporelle a une dimension.
#
# - x represents la variable de l'espace étudier. Dans le cadre d'un signal **sonore, x sera le temps (t)**
#
# - F(f) permet finalement de **passer d'une fonction f(t) du temps, en une fonction F($\omega$) de la fréquence**

# %% [markdown]
# ## Deux types de Transformation de Fourrier

# %% [markdown]
# ### Transformée de Fourier continue (TFC)

# %% [markdown]
# La TFC est utilisée pour analyser des signaux continus dans le domaine du temps. Elle transforme une fonction continue du temps en une fonction continue de la fréquence. La formule mathématique de la transformée de Fourier continue d'une fonction f(t) est donnée par :

# %%
Image(filename=os.path.join(cwd, "images/continue.png"))

# %% [markdown]
# ### Transformée de Fourier discrète (TFD)

# %% [markdown]
# La TFD est utilisée pour analyser des signaux échantillonnés dans le domaine du temps, tels que des séries temporelles numériques. Elle transforme une séquence finie de N échantillons en une séquence de N valeurs complexes dans le domaine de la fréquence. La formule mathématique de la transformée de Fourier discrète d'une séquence x[n] est donnée par :

# %%
Image(filename=os.path.join(cwd, "images/discrete.png"))

# %% [markdown]
# ## Critère de Shannon

# %% [markdown]
# - Le critère de Shannon-Nyquist est utilisé dans le traitement de signal sonore.
#
#
# - Pour garantir un traitement de bonne qualité, un critère sur la fréquence d'échantillonage est nécessaire
#
#
# - Pour être certain de capter l'intégralité des informations il faut échantilloner le signal avec la fréquence du critère :
#
#
# - ** $F_e$ > 2* $F_m$

# %%
Image(filename=os.path.join(cwd, "images/shannon.png"))

# %% [markdown]
# # Code

# %% [markdown]
# ### Signals

# %%
class Signal:
    def __init__(self, signal_type='sinusoidal', frequency=1.0, amplitude=1.0, duration=1.0, sampling_rate=1000):
        self.signal_type = signal_type
        self.frequency = frequency
        self.amplitude = amplitude
        self.duration = duration
        self.sampling_rate = sampling_rate

    def __repr__(self):
        return f"Frequency = {self.frequency} - Amplitude = {self.amplitude} - Duration = {self.duration} - Sampling_rate = {self.sampling_rate}"

    def generate_signal(self):
        t = np.linspace(0, self.duration, int(self.duration * self.sampling_rate), endpoint=False)
        if self.signal_type == 'sinusoidal':
            signal = self.amplitude * np.sin(2 * np.pi * self.frequency * t)
        else:
            raise ValueError("Unsupported signal type. Available types: 'sinusoidal', 'square', 'sawtooth'")
        return t, signal

    def add_signal(self, other_signal):
        if not isinstance(other_signal, Signal):
            raise ValueError("Input must be a Signal object.")

        # Ensure both signals have the same duration and sampling rate
        if self.duration != other_signal.duration or self.sampling_rate != other_signal.sampling_rate:
            raise ValueError("Both signals must have the same duration and sampling rate.")

        # Generate signals
        time, signal1 = self.generate_signal()
        _, signal2 = other_signal.generate_signal()

        # Add the two signals together to create a new signal
        combined_signal = signal1 + signal2

        return time, combined_signal

    def plot_signal(self, color='blue'):
        time, signal = self.generate_signal()
        plt.plot(time, signal, linestyle='-', label=f'Signal - {self.frequency} Hz', color=color)

# %%
signal_1 = Signal(frequency=0.1, amplitude=2, duration=10, sampling_rate=10)

# %% [markdown]
# ### Superposed sinusoide

# %%
def generate_combined_signal(frequencies, amplitudes, duration=1.0, sampling_rate=1000):
    t = np.linspace(0, duration, int(duration * sampling_rate), endpoint=False)
    combined_signal = np.zeros_like(t)

    unique_signals = {}

    for idx, freq in enumerate(frequencies):
        amplitude = amplitudes[idx]  # Vous pouvez ajuster l'amplitude pour chaque fréquence ici si nécessaire
        signal = amplitude * np.sin(2 * np.pi * freq * t)

        key = f"signals_freq_{freq}"
        unique_signals[key] = Signal(
            signal_type="sinusoidal",
            frequency=freq,
            amplitude=amplitude,
            duration=duration,
            sampling_rate=sampling_rate
        )
        
        combined_signal += signal

    return t, combined_signal, unique_signals


def plot_sum_signals(signals_dict):
    # Set the size of the figure to 12x8 inches
    plt.figure(figsize=(12, 8))

    # Generate the combined signal by adding all individual signals together
    combined_signal = np.zeros_like(list(signals_dict.values())[0].generate_signal()[1])
    for signal_obj in signals_dict.values():
        _, signal = signal_obj.generate_signal()
        combined_signal += signal

    # Plot the combined signal on a separate graph
    plt.plot(_, combined_signal, linestyle='-', label='Combined Signal', color='purple')

    # Add labels, title, and legend for the combined signal
    plt.xlabel('Time (s)')
    plt.ylabel('Amplitude')
    plt.title('Combined Signal')
    plt.grid()
    plt.legend()

    plt.show()

def plot_superposed_signals(signals_dict, colors=None):
    # Set the size of the figure to 12x8 inches
    plt.figure(figsize=(12, 8))

    # Create a list of colors if not provided
    if colors is None:
        colors = ['blue', 'red', 'green', 'orange', 'purple', 'brown', 'pink']

    # Plot all the individual signals on the same graph with colors from the list
    for i, (signal_name, signal_obj) in enumerate(signals_dict.items()):
        color = colors[i % len(colors)]  # Pick a color from the list based on the iteration index
        signal_obj.plot_signal(color=color)

    # Add labels, title, and legend
    plt.xlabel('Time (s)')
    plt.ylabel('Amplitude')
    plt.title('Superposed Signals')
    plt.grid()
    plt.legend()

    plt.show()

# %% [markdown]
# #### Inputs

# %%
frequency_list = [1, 5, 0.8, 0.31, 0.11, 0.0005, 20]
amplitude_list = [1, 2, 5, 0.1, 1, 2, 1]
duration=10.0
sampling_rate=100

# %%
t, combined_signal, unique_signals = generate_combined_signal(
    frequencies=frequency_list,
    amplitudes=amplitude_list,
    duration=duration, 
    sampling_rate=sampling_rate
)

# %%
plot_superposed_signals(unique_signals)

# %%
plot_sum_signals(signals_dict=unique_signals)

# %% [markdown]
# ### Fourrier Decomposition

# %%
def compute_fourier_decomposition(time, signal, sampling_rate):
    n = len(signal)
    frequencies = np.fft.fftfreq(n, 1 / sampling_rate)
    positive_frequencies = frequencies[:n // 2]
    fft_result = np.zeros(n // 2, dtype=complex)
    
    for k in range(n // 2):
        print(f"Computing frequency : {k}")
        for i in range(n):
            fft_result[k] += signal[i] * np.exp(-2j * np.pi * k * i / n) * 2 / n
    
    return positive_frequencies, fft_result

# %%
time, signal, unique_signals = generate_combined_signal(
    frequencies=frequency_list,
    amplitudes=amplitude_list,
    duration=duration, 
    sampling_rate=sampling_rate
)

# %%
positive_frequencies, fft_result = compute_fourier_decomposition(time=time, signal=signal, sampling_rate=sampling_rate)
# Out:
# Computing frequency : 0
# Computing frequency : 1
# Computing frequency : 2
# Computing frequency : 3
# Computing frequency : 4
# Computing frequency : 5
# Computing frequency : 6
# Computing frequency : 7
# Computing frequency : 8
# Computing frequency : 9
# Computing frequency : 10
# Computing frequency : 11
# Computing frequency : 12
# Computing frequency : 13
# Computing frequency : 14
# Computing frequency : 15
# Computing frequency : 16
# Computing frequency : 17
# Computing frequency : 18
# Computing frequency : 19
# Computing frequency : 20
# Computing frequency : 21
# Computing frequency : 22
# Computing frequency : 23
# Computing frequency : 24
# Computing frequency : 25
# Computing frequency : 26
# Computing frequency : 27
# Computing frequency : 28
# Computing frequency : 29
# Computing frequency : 30
# Computing frequency : 31
# Computing frequency : 32
# Computing frequency : 33
# Computing frequency : 34
# Computing frequency : 35
# Computing frequency : 36
# Computing frequency : 37
# Computing frequency : 38
# Computing frequency : 39
# Computing frequency : 40
# Computing frequency : 41
# Computing frequency : 42
# Computing frequency : 43
# Computing frequency : 44
# Computing frequency : 45
# Computing frequency : 46
# Computing frequency : 47
# Computing frequency : 48
# Computing frequency : 49
# Computing frequency : 50
# Computing frequency : 51
# Computing frequency : 52
# Computing frequency : 53
# Computing frequency : 54
# Computing frequency : 55
# Computing frequency : 56
# Computing frequency : 57
# Computing frequency : 58
# Computing frequency : 59
# Computing frequency : 60
# Computing frequency : 61
# Computing frequency : 62
# Computing frequency : 63
# Computing frequency : 64
# Computing frequency : 65
# Computing frequency : 66
# Computing frequency : 67
# Computing frequency : 68
# Computing frequency : 69
# Computing frequency : 70
# Computing frequency : 71
# Computing frequency : 72
# Computing frequency : 73
# Computing frequency : 74
# Computing frequency : 75
# Computing frequency : 76
# Computing frequency : 77
# Computing frequency : 78
# Computing frequency : 79
# Computing frequency : 80
# Computing frequency : 81
# Computing frequency : 82
# Computing frequency : 83
# Computing frequency : 84
# Computing frequency : 85
# Computing frequency : 86
# Computing frequency : 87
# Computing frequency : 88
# Computing frequency : 89
# Computing frequency : 90
# Computing frequency : 91
# Computing frequency : 92
# Computing frequency : 93
# Computing frequency : 94
# Computing frequency : 95
# Computing frequency : 96
# Computing frequency : 97
# Computing frequency : 98
# Computing frequency : 99
# Computing frequency : 100
# Computing frequency : 101
# Computing frequency : 102
# Computing frequency : 103
# Computing frequency : 104
# Computing frequency : 105
# Computing frequency : 106
# Computing frequency : 107
# Computing frequency : 108
# Computing frequency : 109
# Computing frequency : 110
# Computing frequency : 111
# Computing frequency : 112
# Computing frequency : 113
# Computing frequency : 114
# Computing frequency : 115
# Computing frequency : 116
# Computing frequency : 117
# Computing frequency : 118
# Computing frequency : 119
# Computing frequency : 120
# Computing frequency : 121
# Computing frequency : 122
# Computing frequency : 123
# Computing frequency : 124
# Computing frequency : 125
# Computing frequency : 126
# Computing frequency : 127
# Computing frequency : 128
# Computing frequency : 129
# Computing frequency : 130
# Computing frequency : 131
# Computing frequency : 132
# Computing frequency : 133
# Computing frequency : 134
# Computing frequency : 135
# Computing frequency : 136
# Computing frequency : 137
# Computing frequency : 138
# Computing frequency : 139
# Computing frequency : 140
# Computing frequency : 141
# Computing frequency : 142
# Computing frequency : 143
# Computing frequency : 144
# Computing frequency : 145
# Computing frequency : 146
# Computing frequency : 147
# Computing frequency : 148
# Computing frequency : 149
# Computing frequency : 150
# Computing frequency : 151
# Computing frequency : 152
# Computing frequency : 153
# Computing frequency : 154
# Computing frequency : 155
# Computing frequency : 156
# Computing frequency : 157
# Computing frequency : 158
# Computing frequency : 159
# Computing frequency : 160
# Computing frequency : 161
# Computing frequency : 162
# Computing frequency : 163
# Computing frequency : 164
# Computing frequency : 165
# Computing frequency : 166
# Computing frequency : 167
# Computing frequency : 168
# Computing frequency : 169
# Computing frequency : 170
# Computing frequency : 171
# Computing frequency : 172
# Computing frequency : 173
# Computing frequency : 174
# Computing frequency : 175
# Computing frequency : 176
# Computing frequency : 177
# Computing frequency : 178
# Computing frequency : 179
# Computing frequency : 180
# Computing frequency : 181
# Computing frequency : 182
# Computing frequency : 183
# Computing frequency : 184
# Computing frequency : 185
# Computing frequency : 186
# Computing frequency : 187
# Computing frequency : 188
# Computing frequency : 189
# Computing frequency : 190
# Computing frequency : 191
# Computing frequency : 192
# Computing frequency : 193
# Computing frequency : 194
# Computing frequency : 195
# Computing frequency : 196
# Computing frequency : 197
# Computing frequency : 198
# Computing frequency : 199
# Computing frequency : 200
# Computing frequency : 201
# Computing frequency : 202
# Computing frequency : 203
# Computing frequency : 204
# Computing frequency : 205
# Computing frequency : 206
# Computing frequency : 207
# Computing frequency : 208
# Computing frequency : 209
# Computing frequency : 210
# Computing frequency : 211
# Computing frequency : 212
# Computing frequency : 213
# Computing frequency : 214
# Computing frequency : 215
# Computing frequency : 216
# Computing frequency : 217
# Computing frequency : 218
# Computing frequency : 219
# Computing frequency : 220
# Computing frequency : 221
# Computing frequency : 222
# Computing frequency : 223
# Computing frequency : 224
# Computing frequency : 225
# Computing frequency : 226
# Computing frequency : 227
# Computing frequency : 228
# Computing frequency : 229
# Computing frequency : 230
# Computing frequency : 231
# Computing frequency : 232
# Computing frequency : 233
# Computing frequency : 234
# Computing frequency : 235
# Computing frequency : 236
# Computing frequency : 237
# Computing frequency : 238
# Computing frequency : 239
# Computing frequency : 240
# Computing frequency : 241
# Computing frequency : 242
# Computing frequency : 243
# Computing frequency : 244
# Computing frequency : 245
# Computing frequency : 246
# Computing frequency : 247
# Computing frequency : 248
# Computing frequency : 249
# Computing frequency : 250
# Computing frequency : 251
# Computing frequency : 252
# Computing frequency : 253
# Computing frequency : 254
# Computing frequency : 255
# Computing frequency : 256
# Computing frequency : 257
# Computing frequency : 258
# Computing frequency : 259
# Computing frequency : 260
# Computing frequency : 261
# Computing frequency : 262
# Computing frequency : 263
# Computing frequency : 264
# Computing frequency : 265
# Computing frequency : 266
# Computing frequency : 267
# Computing frequency : 268
# Computing frequency : 269
# Computing frequency : 270
# Computing frequency : 271
# Computing frequency : 272
# Computing frequency : 273
# Computing frequency : 274
# Computing frequency : 275
# Computing frequency : 276
# Computing frequency : 277
# Computing frequency : 278
# Computing frequency : 279
# Computing frequency : 280
# Computing frequency : 281
# Computing frequency : 282
# Computing frequency : 283
# Computing frequency : 284
# Computing frequency : 285
# Computing frequency : 286
# Computing frequency : 287
# Computing frequency : 288
# Computing frequency : 289
# Computing frequency : 290
# Computing frequency : 291
# Computing frequency : 292
# Computing frequency : 293
# Computing frequency : 294
# Computing frequency : 295
# Computing frequency : 296
# Computing frequency : 297
# Computing frequency : 298
# Computing frequency : 299
# Computing frequency : 300
# Computing frequency : 301
# Computing frequency : 302
# Computing frequency : 303
# Computing frequency : 304
# Computing frequency : 305
# Computing frequency : 306
# Computing frequency : 307
# Computing frequency : 308
# Computing frequency : 309
# Computing frequency : 310
# Computing frequency : 311
# Computing frequency : 312
# Computing frequency : 313
# Computing frequency : 314
# Computing frequency : 315
# Computing frequency : 316
# Computing frequency : 317
# Computing frequency : 318
# Computing frequency : 319
# Computing frequency : 320
# Computing frequency : 321
# Computing frequency : 322
# Computing frequency : 323
# Computing frequency : 324
# Computing frequency : 325
# Computing frequency : 326
# Computing frequency : 327
# Computing frequency : 328
# Computing frequency : 329
# Computing frequency : 330
# Computing frequency : 331
# Computing frequency : 332
# Computing frequency : 333
# Computing frequency : 334
# Computing frequency : 335
# Computing frequency : 336
# Computing frequency : 337
# Computing frequency : 338
# Computing frequency : 339
# Computing frequency : 340
# Computing frequency : 341
# Computing frequency : 342
# Computing frequency : 343
# Computing frequency : 344
# Computing frequency : 345
# Computing frequency : 346
# Computing frequency : 347
# Computing frequency : 348
# Computing frequency : 349
# Computing frequency : 350
# Computing frequency : 351
# Computing frequency : 352
# Computing frequency : 353
# Computing frequency : 354
# Computing frequency : 355
# Computing frequency : 356
# Computing frequency : 357
# Computing frequency : 358
# Computing frequency : 359
# Computing frequency : 360
# Computing frequency : 361
# Computing frequency : 362
# Computing frequency : 363
# Computing frequency : 364
# Computing frequency : 365
# Computing frequency : 366
# Computing frequency : 367
# Computing frequency : 368
# Computing frequency : 369
# Computing frequency : 370
# Computing frequency : 371
# Computing frequency : 372
# Computing frequency : 373
# Computing frequency : 374
# Computing frequency : 375
# Computing frequency : 376
# Computing frequency : 377
# Computing frequency : 378
# Computing frequency : 379
# Computing frequency : 380
# Computing frequency : 381
# Computing frequency : 382
# Computing frequency : 383
# Computing frequency : 384
# Computing frequency : 385
# Computing frequency : 386
# Computing frequency : 387
# Computing frequency : 388
# Computing frequency : 389
# Computing frequency : 390
# Computing frequency : 391
# Computing frequency : 392
# Computing frequency : 393
# Computing frequency : 394
# Computing frequency : 395
# Computing frequency : 396
# Computing frequency : 397
# Computing frequency : 398
# Computing frequency : 399
# Computing frequency : 400
# Computing frequency : 401
# Computing frequency : 402
# Computing frequency : 403
# Computing frequency : 404
# Computing frequency : 405
# Computing frequency : 406
# Computing frequency : 407
# Computing frequency : 408
# Computing frequency : 409
# Computing frequency : 410
# Computing frequency : 411
# Computing frequency : 412
# Computing frequency : 413
# Computing frequency : 414
# Computing frequency : 415
# Computing frequency : 416
# Computing frequency : 417
# Computing frequency : 418
# Computing frequency : 419
# Computing frequency : 420
# Computing frequency : 421
# Computing frequency : 422
# Computing frequency : 423
# Computing frequency : 424
# Computing frequency : 425
# Computing frequency : 426
# Computing frequency : 427
# Computing frequency : 428
# Computing frequency : 429
# Computing frequency : 430
# Computing frequency : 431
# Computing frequency : 432
# Computing frequency : 433
# Computing frequency : 434
# Computing frequency : 435
# Computing frequency : 436
# Computing frequency : 437
# Computing frequency : 438
# Computing frequency : 439
# Computing frequency : 440
# Computing frequency : 441
# Computing frequency : 442
# Computing frequency : 443
# Computing frequency : 444
# Computing frequency : 445
# Computing frequency : 446
# Computing frequency : 447
# Computing frequency : 448
# Computing frequency : 449
# Computing frequency : 450
# Computing frequency : 451
# Computing frequency : 452
# Computing frequency : 453
# Computing frequency : 454
# Computing frequency : 455
# Computing frequency : 456
# Computing frequency : 457
# Computing frequency : 458
# Computing frequency : 459
# Computing frequency : 460
# Computing frequency : 461
# Computing frequency : 462
# Computing frequency : 463
# Computing frequency : 464
# Computing frequency : 465
# Computing frequency : 466
# Computing frequency : 467
# Computing frequency : 468
# Computing frequency : 469
# Computing frequency : 470
# Computing frequency : 471
# Computing frequency : 472
# Computing frequency : 473
# Computing frequency : 474
# Computing frequency : 475
# Computing frequency : 476
# Computing frequency : 477
# Computing frequency : 478
# Computing frequency : 479
# Computing frequency : 480
# Computing frequency : 481
# Computing frequency : 482
# Computing frequency : 483
# Computing frequency : 484
# Computing frequency : 485
# Computing frequency : 486
# Computing frequency : 487
# Computing frequency : 488
# Computing frequency : 489
# Computing frequency : 490
# Computing frequency : 491
# Computing frequency : 492
# Computing frequency : 493
# Computing frequency : 494
# Computing frequency : 495
# Computing frequency : 496
# Computing frequency : 497
# Computing frequency : 498
# Computing frequency : 499

# %%
# Plot the Fourier decomposition
plt.figure(figsize=(12, 8))
plt.plot(positive_frequencies, np.abs(fft_result), linestyle='-', marker='o', label='Fourier Decomposition', color='blue')
plt.xlabel('Frequency (Hz)')
plt.ylabel('Amplitude')
plt.title('Fourier Decomposition')
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# ### Re-build signal from Fourrier

# %%
def reconstruct_signal(positive_frequencies, fft_result, duration, sampling_rate):
    n = len(fft_result)
    frequencies = np.fft.fftfreq(n, 1 / sampling_rate)
    combined_signal = np.zeros(n)

    for k, freq in enumerate(frequencies[:n // 2]):
        amplitude = np.abs(fft_result[k])  # The amplitude of the frequency component
        phase_angle = 0 # np.angle(fft_result[k])  # The phase angle of the frequency component

        # Reconstruct the individual frequency component
        frequency_component = amplitude * np.exp(1j * phase_angle) * np.exp(2j * np.pi * freq * duration * np.arange(n))

        # Add the frequency component to the combined signal
        combined_signal += frequency_component.real

    return np.linspace(0, duration, n), combined_signal
